# %%
import pandas as pd
archivo=pd.read_csv("C:/Users/Ariadna Cordero/Downloads/indicadores_geo.csv")

# %%
archivo.head()
# Out:
#    Unnamed: 0  clave_entidad entidad_federativa clave_municipio  \
# 0           0              1     Aguascalientes            1001
# 1           1              1     Aguascalientes            1002
# 2           2              1     Aguascalientes            1003
# 3           3              1     Aguascalientes            1004
# 4           4              1     Aguascalientes            1005
#
#          mun_name  poblacion  pobreza  pobreza_pob  pobreza_e  pobreza_e_pob  \
# 0  Aguascalientes     861446     26.1       224949        1.6          13650
# 1        Asientos      46624     54.0        25169        4.4           2067
# 2        Calvillo      52773     56.8        29951        3.1           1650
# 3           Cosío      15321     43.2         6620        2.8            432
# 4     Jesús María     125750     25.0        31479        1.7           2095
#
#    pobreza_m  pobreza_m_pob  vul_car  vul_car_pob  vul_ing  vul_ing_pob  npnv  \
# ...

# %%
pd.options.display.max_columns = None

# %%
import seaborn as sb
sb.set(rc={'axes.facecolor':'lavender', 'figure.facecolor':'lavender'})
fig, ax = plt.subplots(figsize=(12,12))         # Sample figsize in inches
p=sb.heatmap(archivo[["pobreza","pobreza_e","pobreza_m","vul_car","vul_ing","carencias3","plb","npnv","ic_rezedu","ic_asalud","ic_segsoc","ic_cv","ic_sbv","ic_sbv","ic_ali","carencias","carencias3","plbm"]].corr(),cmap="YlGnBu",annot=True, linewidths=.5, ax=ax,vmin=-1,vmax=1)
p.set_title("Análisis de Correlación entre variables",fontsize = 20)
fig.savefig("C:/Users/Ariadna Cordero/Pictures/mapa50.png")

# %%
list(archivo.columns.values)
# Out:
# ['Unnamed: 0',
#  'clave_entidad',
#  'entidad_federativa',
#  'clave_municipio',
#  'mun_name',
#  'poblacion',
#  'pobreza',
#  'pobreza_pob',
#  'pobreza_e',
#  'pobreza_e_pob',
#  'pobreza_m',
#  'pobreza_m_pob',
#  'vul_car',
#  'vul_car_pob',
#  'vul_ing',
#  'vul_ing_pob',
#  'npnv',
#  'npnv_pob',
#  'ic_rezedu',
#  'ic_rezedu_pob',
#  'ic_asalud',
#  'ic_asalud_pob',
#  'ic_segsoc',
#  'ic_segsoc_pob',
#  'ic_cv',
#  'ic_cv_pob',
#  'ic_sbv',
#  'ic_sbv_pob',
#  'ic_ali',
#  'ic_ali_pob',
#  'carencias',
#  'carencias_pob',
#  'carencias3',
#  'carencias3_pob',
#  'plb',
#  'plb_pob',
#  'plbm',
#  'plbm_pob',
#  'direccion',
#  'lat',
#  'long']

# %%
archivo.drop(['Unnamed: 0'],axis=1)
# Out:
#       clave_entidad entidad_federativa clave_municipio               mun_name  \
# 0                 1     Aguascalientes            1001         Aguascalientes
# 1                 1     Aguascalientes            1002               Asientos
# 2                 1     Aguascalientes            1003               Calvillo
# 3                 1     Aguascalientes            1004                  Cosío
# 4                 1     Aguascalientes            1005            Jesús María
# ...             ...                ...             ...                    ...
# 2441             32          Zacatecas           32054          Villa Hidalgo
# 2442             32          Zacatecas           32055             Villanueva
# 2443             32          Zacatecas           32056              Zacatecas
# 2444             32          Zacatecas           32057               Trancoso
# 2445             32          Zacatecas           32058  Santa María de la Paz
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
# %matplotlib inline

# %%
nuevo=archivo.iloc[:,[2,6]]

# %%
np.array(archivo["pobreza"])
# Out:
# array(['Aguascalientes', 'Aguascalientes', 'Aguascalientes', ...,
#        'Zacatecas', 'Zacatecas', 'Zacatecas'], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
fig = plt.figure(dpi=100, figsize=(10,7))
ax = fig.gca()
sns.set()
sns.set_style("darkgrid")
sns.barplot(x=np.array(archivo["ic_rezedu"]), y=np.array(archivo["entidad_federativa"]), ax=ax, orient="h")
ax.set_ylabel("Entidad federativa")
ax.set_xlabel("Porcentaje")
ax.set_title(f"Porcentaje de la población con rezago educativo")
#fig.savefig("C:/Users/Ariadna Cordero/Downloads/pobreza_e.png")
# Out:
# Text(0.5, 1.0, 'Porcentaje de la población con rezago educativo')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
fig = plt.figure(dpi=100, figsize=(10,7))
ax = fig.gca()
sns.set()
sns.set_style("darkgrid")
sns.barplot(x=np.array(archivo["ic_segsoc"]), y=np.array(archivo["entidad_federativa"]), ax=ax, orient="h",palette="dark")
ax.set_ylabel("Entidad federativa")
ax.set_xlabel("Porcentaje")
ax.set_title(f"Porcentaje de la población con carencia por acceso a la seguridad social")
#fig.savefig("C:/Users/Ariadna Cordero/Downloads/pobreza_e.png")
# Out:
# Text(0.5, 1.0, 'Porcentaje de la población con carencia por acceso a la seguridad social')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
fig = plt.figure(dpi=100, figsize=(10,7))
ax = fig.gca()
sns.set()
sns.set_style("darkgrid")
sns.barplot(x=np.array(archivo["plbm"]), y=np.array(archivo["entidad_federativa"]), ax=ax, orient="h",palette="bright")
ax.set_ylabel("Entidad federativa")
ax.set_xlabel("Porcentaje")
ax.set_title(f"Porcentaje de la población con ingreso inferior a la línea de bienestar mínimo")
fig.savefig("C:/Users/Ariadna Cordero/Downloads/pobreza_e.png")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
fig = plt.figure(dpi=100, figsize=(10,7))
ax = fig.gca()
sns.set()
sns.set_style("darkgrid")
sns.barplot(x=np.array(archivo["plb"]), y=np.array(archivo["entidad_federativa"]), ax=ax, orient="h",palette="pastel")
ax.set_ylabel("Entidad federativa")
ax.set_xlabel("Porcentaje")
ax.set_title(f"Porcentaje de población con ingreso inferior a la linea de bienestar")
fig.savefig("C:/Users/Ariadna Cordero/Downloads/pobreza_e.png")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
fig = plt.figure(dpi=100, figsize=(10,7))
ax = fig.gca()
sns.set()
sns.set_style("darkgrid")
sns.barplot(x=np.array(archivo["npnv"]), y=np.array(archivo["entidad_federativa"]), ax=ax, orient="h",palette="pastel")
ax.set_ylabel("Entidad federativa")
ax.set_xlabel("Porcentaje")
ax.set_title(f"Porcentaje de población no pobre y no vulnerable")
fig.savefig("C:/Users/Ariadna Cordero/Downloads/pobreza_e.png")

# %%
#Sonora,Nuevo León,Distrito Federal,Coahuila,Baja California,Baja California Sur"
nopobre=archivo[archivo.entidad_federativa.isin(["Sonora","Nuevo León","Distrito Federal","Coahuila","Baja California","Baja California Sur"])]
nopobre
# Out:
#       Unnamed: 0  clave_entidad entidad_federativa clave_municipio  \
# 11            11              2    Baja California            2001
# 12            12              2    Baja California            2002
# 13            13              2    Baja California            2003
# 14            14              2    Baja California            2004
# 15            15              2    Baja California            2005
# ...          ...            ...                ...             ...
# 1945        1955             26             Sonora           26067
# 1946        1956             26             Sonora           26068
# 1947        1957             26             Sonora           26069
# 1948        1959             26             Sonora           26071
# 1949        1960             26             Sonora           26072
#
#                     mun_name  poblacion  pobreza  pobreza_pob  pobreza_e  \
# 11                  Ensenada     569425     33.5       190776        3.5
# ...

# %%
#DIVIDIR EN ESTRATOS
# Datos agrupados 
nop =nopobre.groupby('entidad_federativa')

# %%
mednop=nop.mean()
mednop
# Out:
#                       Unnamed: 0  clave_entidad      poblacion    pobreza  \
# entidad_federativa
# Baja California        13.000000            2.0  699894.800000  30.620000
# Baja California Sur    18.000000            3.0  154042.000000  31.960000
# Coahuila               50.500000            5.0   78159.921053  29.347368
# Distrito Federal      272.500000            9.0  552897.437500  26.393750
# Nuevo León            972.000000           19.0  100137.784314  29.554902
# Sonora               1924.028169           26.0   41473.619718  29.102817
#
#                        pobreza_pob  pobreza_e  pobreza_e_pob  pobreza_m  \
# entidad_federativa
# Baja California      204393.200000   2.300000   14705.400000  28.280000
# Baja California Sur   43021.800000   2.680000    3813.800000  29.240000
# Coahuila              19095.736842   2.589474    1623.894737  26.755263
# Distrito Federal     153567.750000   1.062500    6608.437500  25.306250
# ...

# %%
mednop.to_csv("C:/Users/Ariadna Cordero/Downloads/comparacion2.csv")

# %%
#Yucatan,Veracruz,Oaxaca,Guerrero,Chiapas

# %%
masde3=archivo[archivo.entidad_federativa.isin(["Yucatán","Veracruz","Oaxaca","Guerrero","Chiapas"])]
masde3
# Out:
#       Unnamed: 0  clave_entidad entidad_federativa clave_municipio  \
# 80            80              7            Chiapas            7001
# 81            81              7            Chiapas            7002
# 82            82              7            Chiapas            7003
# 83            83              7            Chiapas            7004
# 84            84              7            Chiapas            7005
# ...          ...            ...                ...             ...
# 2383        2394             31            Yucatán           31102
# 2384        2395             31            Yucatán           31103
# 2385        2396             31            Yucatán           31104
# 2386        2397             31            Yucatán           31105
# 2387        2398             31            Yucatán           31106
#
#         mun_name  poblacion  pobreza  pobreza_pob  pobreza_e  pobreza_e_pob  \
# 80    Acacoyagua      20706     78.8        16311       24.6           5087
# ...

# %%
#DIVIDIR EN ESTRATOS
# Datos agrupados 
tresgrupo =masde3.groupby('entidad_federativa')
tresgrupo.head()
# Out:
#       Unnamed: 0  clave_entidad entidad_federativa clave_municipio  \
# 80            80              7            Chiapas            7001
# 81            81              7            Chiapas            7002
# 82            82              7            Chiapas            7003
# 83            83              7            Chiapas            7004
# 84            84              7            Chiapas            7005
# 361          366             12           Guerrero           12001
# 362          367             12           Guerrero           12002
# 363          368             12           Guerrero           12003
# 364          369             12           Guerrero           12004
# 365          370             12           Guerrero           12005
# 993          998             20             Oaxaca           20001
# 994          999             20             Oaxaca           20002
# 995         1000             20             Oaxaca           20003
# ...

# %%
media3=tresgrupo.mean()
media3
media3.to_csv("C:/Users/Ariadna Cordero/Downloads/comparacion1.csv")

# %%
sns.barplot(x='Food', y='Age', hue='Gender', data=df, estimator=np.median)

# %%
pd.options.display.max_columns = None

# %%
import geopandas as gpd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
archivo.columns.values
# Out:
# array(['Unnamed: 0', 'clave_entidad', 'entidad_federativa',
#        'clave_municipio', 'mun_name', 'poblacion', 'pobreza',
#        'pobreza_pob', 'pobreza_e', 'pobreza_e_pob', 'pobreza_m',
#        'pobreza_m_pob', 'vul_car', 'vul_car_pob', 'vul_ing',
#        'vul_ing_pob', 'npnv', 'npnv_pob', 'ic_rezedu', 'ic_rezedu_pob',
#        'ic_asalud', 'ic_asalud_pob', 'ic_segsoc', 'ic_segsoc_pob',
#        'ic_cv', 'ic_cv_pob', 'ic_sbv', 'ic_sbv_pob', 'ic_ali',
#        'ic_ali_pob', 'carencias', 'carencias_pob', 'carencias3',
#        'carencias3_pob', 'plb', 'plb_pob', 'plbm', 'plbm_pob',
#        'direccion', 'lat', 'long'], dtype=object)

# %%
# !git clone https://github.com/jschleuss/mexican-states.git
# Out:
# "git" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %%
fig,ax=plt.subplots()
ax.scatter(archivo["ic_rezedu"],archivo["npnv"])
plt.show()

# %%
fig,ax=plt.subplots()
ax.scatter(archivo["poblacion"],archivo["pobreza_e"])
plt.show()

# %%
# Tratamiento de datos
# ==============================================================================
import numpy as np
import pandas as pd
import statsmodels.api as sm

# Gráficos
# ==============================================================================
import matplotlib.pyplot as plt
import matplotlib.font_manager
from matplotlib import style
style.use('ggplot') or plt.style.use('ggplot')

# Preprocesado y modelado
# ==============================================================================
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import scale

# Configuración warnings
# ==============================================================================
import warnings
warnings.filterwarnings('ignore')

# %%
print('----------------------')
print('Media de cada variable')
print('----------------------')
archivo.mean(axis=0)
# Out:
# ----------------------
# Media de cada variable
# ----------------------
# Unnamed: 0         1229.499182
# clave_entidad        19.278005
# poblacion         49619.276778
# pobreza              65.529436
# pobreza_pob       21821.629191
# pobreza_e            19.713696
# pobreza_e_pob      3949.838921
# pobreza_m            45.815249
# pobreza_m_pob     17871.787817
# vul_car              22.472854
# vul_car_pob       13193.248160
# vul_ing               3.740188
# vul_ing_pob        3838.073590
# npnv                  8.256378
# npnv_pob          10766.312756
# ic_rezedu            27.859648
# ic_rezedu_pob      8815.699101
# ic_asalud            14.167539
# ic_asalud_pob      8370.977923
# ic_segsoc            73.993213
# ic_segsoc_pob     28061.201962
# ic_cv                19.830294
# ic_cv_pob          5981.464432
# ic_sbv               45.975797
# ic_sbv_pob        10113.769419
# ic_ali               24.422363
# ic_ali_pob        10724.311120
# carencias            88.003271
# ...

# %%
print('-------------------------')
print('Varianza de cada variable')
print('-------------------------')
archivo.var(axis=0)
# Out:
# -------------------------
# Varianza de cada variable
# -------------------------
# Unnamed: 0        5.031516e+05
# clave_entidad     5.391205e+01
# poblacion         2.086044e+10
# pobreza           4.624732e+02
# pobreza_pob       2.422252e+09
# pobreza_e         3.226737e+02
# pobreza_e_pob     4.927051e+07
# pobreza_m         1.380411e+02
# pobreza_m_pob     1.956824e+09
# vul_car           1.599379e+02
# vul_car_pob       1.647923e+09
# vul_ing           1.689944e+01
# vul_ing_pob       2.420020e+08
# npnv              9.380178e+01
# npnv_pob          2.095120e+09
# ic_rezedu         1.013925e+02
# ic_rezedu_pob     3.499637e+08
# ic_asalud         4.903211e+01
# ic_asalud_pob     7.694682e+08
# ic_segsoc         2.473223e+02
# ic_segsoc_pob     4.476422e+09
# ic_cv             1.922753e+02
# ic_cv_pob         1.633110e+08
# ic_sbv            9.329741e+02
# ic_sbv_pob        2.779438e+08
# ic_ali            1.388774e+02
# ic_ali_pob        7.853315e+08
# ...

# %%
archivo2
# Out:
#       pobreza  pobreza_pob  pobreza_e  pobreza_e_pob  pobreza_m  \
# 0        26.1       224949        1.6          13650       24.5
# 1        54.0        25169        4.4           2067       49.5
# 2        56.8        29951        3.1           1650       53.6
# 3        43.2         6620        2.8            432       40.4
# 4        25.0        31479        1.7           2095       23.4
# ...       ...          ...        ...            ...        ...
# 2441     71.8        13040        9.2           1674       62.6
# 2442     61.0        18269        6.9           2071       54.1
# 2443     25.9        39133        1.8           2768       24.1
# 2444     63.1        11815        7.7           1439       55.4
# 2445     57.4         1525        5.9            156       51.5
#
#       pobreza_m_pob  vul_car  vul_car_pob  vul_ing  vul_ing_pob  ...  ic_ali  \
# 0            211299     26.4       227805     11.5        98641  ...    18.0
# ...

# %%
archivo2=archivo2.drop([10],axis=0)

# %%
archivo2.shape
# Out:
# (2445, 32)

# %%
list(archivo["clave_municipio"])
# Out:
# ['1001',
#  '1002',
#  '1003',
#  '1004',
#  '1005',
#  '1006',
#  '1007',
#  '1008',
#  '1009',
#  '1010',
#  '-',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '3001',
#  '3002',
#  '3003',
#  '3008',
#  '3009',
#  '4001',
#  '4002',
#  '4003',
#  '4004',
#  '4005',
#  '4006',
#  '4007',
#  '4008',
#  '4009',
#  '4010',
#  '4011',
#  '5001',
#  '5002',
#  '5003',
#  '5004',
#  '5005',
#  '5006',
#  '5007',
#  '5008',
#  '5009',
#  '5010',
#  '5011',
#  '5012',
#  '5013',
#  '5014',
#  '5015',
#  '5016',
#  '5017',
#  '5018',
#  '5019',
#  '5020',
#  '5021',
#  '5022',
#  '5023',
#  '5024',
#  '5025',
#  '5026',
#  '5027',
#  '5028',
#  '5029',
#  '5030',
#  '5031',
#  '5032',
#  '5033',
#  '5034',
#  '5035',
#  '5036',
#  '5037',
#  '5038',
#  '6001',
#  '6002',
#  '6003',
#  '6004',
#  '6005',
#  '6006',
#  '6007',
#  '6008',
#  '6009',
#  '6010',
#  '7001',
#  '7002',
#  '7003',
#  '7004',
#  '7005',
#  '7006',
#  '7007',
#  '7008',
#  '7009',
#  '7010',
#  '7011',
# ...

# %%
archivo2=archivo.drop([10],axis=0)

# %%
archivo2.mean()
# Out:
# pobreza              65.543436
# pobreza_pob       21824.771779
# pobreza_e            19.721022
# pobreza_e_pob      3951.126789
# pobreza_m            45.821922
# pobreza_m_pob     17873.642536
# vul_car              22.470429
# vul_car_pob       13193.407362
# vul_ing               3.736115
# vul_ing_pob        3837.117382
# npnv                  8.248834
# npnv_pob          10765.794274
# ic_rezedu            27.864131
# ic_rezedu_pob      8816.179141
# ic_asalud            14.168589
# ic_asalud_pob      8372.264213
# ic_segsoc            74.008139
# ic_segsoc_pob     28065.749284
# ic_cv                19.836196
# ic_cv_pob          5982.905930
# ic_sbv               45.993292
# ic_sbv_pob        10117.310429
# ic_ali               24.423804
# ic_ali_pob        10724.830675
# carencias            88.014847
# carencias_pob     35018.193865
# carencias3           35.647157
# carencias3_pob    10137.513701
# plb                  69.280777
# plb_pob           25661.894888
# ...

# %%
archivo2.std()
# Out:
# pobreza              21.498437
# pobreza_pob       49226.200283
# pobreza_e            17.963140
# pobreza_e_pob      7020.442176
# pobreza_m            11.746858
# pobreza_m_pob     44244.958687
# vul_car              12.648674
# vul_car_pob       40602.921816
# vul_ing               4.106794
# vul_ing_pob       15559.525393
# npnv                  9.679924
# npnv_pob          45781.835900
# ic_rezedu            10.069002
# ic_rezedu_pob     18711.129273
# ic_asalud             7.003533
# ic_asalud_pob     27744.890859
# ic_segsoc            15.712363
# ic_segsoc_pob     66919.377427
# ic_cv                13.866099
# ic_cv_pob         12781.735326
# ic_sbv               30.538612
# ic_sbv_pob        16674.136785
# ic_ali               11.786823
# ic_ali_pob        28029.487466
# carencias            13.029695
# carencias_pob     87354.856663
# carencias3           20.635725
# carencias3_pob    19314.043620
# plb                  19.073184
# plb_pob           63552.959958
# ...

# %%
num=archivo2.values

# %%
num=num-num.mean(axis=0)

# %%
num=num/num.std(axis=0)

# %%
num
# Out:
# array([[-1.83508706,  4.12718793, -1.00899561, ...,  4.68883039,
#         -1.16721156,  4.16843948],
#        [-0.53705284,  0.06794984, -0.85308898, ...,  0.0485223 ,
#         -0.54079018,  0.12230725],
#        [-0.40678418,  0.1651131 , -0.9254742 , ...,  0.12019373,
#         -0.43638661,  0.26971088],
#        ...,
#        [-1.84439196,  0.35167794, -0.99785943, ...,  0.42483666,
#         -1.23246379,  0.20282729],
#        [-0.11367968, -0.20338396, -0.66934186, ..., -0.19557605,
#         -0.29283171, -0.18895034],
#        [-0.37886946, -0.41246174, -0.76956756, ..., -0.37872064,
#         -0.44943706, -0.45616001]])

# %%
# Datos agrupados por sexo
agrupados =archivo.groupby('entidad_federativa')
agrupados.head()
# Out:
#       Unnamed: 0  clave_entidad entidad_federativa clave_municipio  \
# 0              0              1     Aguascalientes            1001
# 1              1              1     Aguascalientes            1002
# 2              2              1     Aguascalientes            1003
# 3              3              1     Aguascalientes            1004
# 4              4              1     Aguascalientes            1005
# ...          ...            ...                ...             ...
# 2388        2399             32          Zacatecas           32001
# 2389        2400             32          Zacatecas           32002
# 2390        2401             32          Zacatecas           32003
# 2391        2402             32          Zacatecas           32004
# 2392        2403             32          Zacatecas           32005
#
#             mun_name  poblacion  pobreza  pobreza_pob  pobreza_e  \
# 0     Aguascalientes     861446     26.1       224949        1.6
# ...

# %%
#promedios=agrupados.mean()
promedios.head()
# Out:
#                          poblacion    pobreza    pobreza_pob  pobreza_e  \
# entidad_federativa
# Aguascalientes       117536.454545  44.254545   36395.909091   3.145455
# Baja California      699894.800000  30.620000  204393.200000   2.300000
# Baja California Sur  154042.000000  31.960000   43021.800000   2.680000
# Campeche              82889.545455  56.109091   34888.181818  12.200000
# Chiapas               44681.279661  83.485593   32414.610169  38.705085
#
#                      pobreza_e_pob  pobreza_m  pobreza_m_pob    vul_car  \
# entidad_federativa
# Aguascalientes         2321.000000  41.081818   34074.818182  28.627273
# Baja California       14705.400000  28.280000  189687.600000  36.000000
# Baja California Sur    3813.800000  29.240000   39208.200000  33.100000
# Campeche               5898.909091  43.918182   28988.909091  29.063636
# Chiapas               13382.788136  44.784746   19031.754237  12.086441
#
# ...

# %%
nuevo=promedios.reset_index()
nuevo
# Out:
#      entidad_federativa      poblacion    pobreza    pobreza_pob  pobreza_e  \
# 0        Aguascalientes  117536.454545  44.254545   36395.909091   3.145455
# 1       Baja California  699894.800000  30.620000  204393.200000   2.300000
# 2   Baja California Sur  154042.000000  31.960000   43021.800000   2.680000
# 3              Campeche   82889.545455  56.109091   34888.181818  12.200000
# 4               Chiapas   44681.279661  83.485593   32414.610169  38.705085
# 5             Chihuahua   60008.709677  48.822581   17587.645161   7.829032
# 6              Coahuila   78159.921053  29.347368   19095.736842   2.589474
# 7                Colima   72754.000000  41.120000   24194.100000   4.840000
# 8      Distrito Federal  552897.437500  26.393750  153567.750000   1.062500
# 9               Durango   45369.589744  57.302564   17820.435897   8.107692
# 10           Guanajuato  126764.695652  54.291304   53290.217391   5.980435
# ...

# %%
shape = mex.merge(
                     right = nuevo,
                     left_on = 'name',
                     right_on = 'entidad_federativa',
                     how = 'left'
                     )

# %%
final = shape.merge(
                     right = by_year,
                     left_on = 'name',
                     right_on = 'entidad',
                     how = 'left'
                     )

# %%
shape.columns.values
# Out:
# array(['ISO3166-2', 'admin_leve', 'boundary', 'is_in_coun', 'is_in_co_1',
#        'name', 'name_en', 'name_es', 'name_pl', 'name_ru', 'name_uk',
#        'place', 'ref', 'type', 'wikidata', 'wikipedia', 'geometry',
#        'entidad_federativa', 'poblacion', 'pobreza', 'pobreza_pob',
#        'pobreza_e', 'pobreza_e_pob', 'pobreza_m', 'pobreza_m_pob',
#        'vul_car', 'vul_car_pob', 'vul_ing', 'vul_ing_pob', 'npnv',
#        'npnv_pob', 'ic_rezedu', 'ic_rezedu_pob', 'ic_asalud',
#        'ic_asalud_pob', 'ic_segsoc', 'ic_segsoc_pob', 'ic_cv',
#        'ic_cv_pob', 'ic_sbv', 'ic_sbv_pob', 'ic_ali', 'ic_ali_pob',
#        'carencias', 'carencias_pob', 'carencias3', 'carencias3_pob',
#        'plb', 'plb_pob', 'plbm', 'plbm_pob'], dtype=object)

# %%
shape.plot(
            column = 'plb', 
            legend = True, 
            legend_kwds = {
              'label': "Porcentaje de la población con ingreso inferior a la línea de bienestar",
              'orientation': "horizontal"
              },
            cmap = 'Oranges'
            )
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mplc
import matplotlib.ticker as ticker

# %%
#creando una figura en matplotlib y ajustando el tamaño deseado 
from mpl_toolkits.axes_grid1 import make_axes_locatable
fig , ax = plt.subplots(1 ,figsize = (14,8))
divider = make_axes_locatable(ax)
cax = divider.append_axes("bottom", size="5%", pad=0)
final.plot(
  column = 'IM', 
  legend = True, 
  cmap ='cool',
  ax = ax,cax=cax,
  linewidth = 1, #ajustando el grosor de las lineas del mapa
  edgecolor ='black',legend_kwds={'label': "Indice",'orientation': "horizontal"})

ax.set_title('Indice calculado por Anáisis de Componentes Principales', fontsize = 23)

ax.axis('off') #desactivando los ejes de posicionamiento

plt.show()

# %%
vmin = shape.plb.min()
vmax = shape.plb.max()

#agregando barra de color atraves de matplotlib

#ajsutando posición y dimensiones de la barra
cax = fig.add_axes([0.9, 0.2, 0.01, 0.6]) 
#atributos de la barra de color
sm = plt.cm.ScalarMappable(
                      cmap = 'Oranges', 
                      )
sm._A = []

# %%
archivo3=

# %%
scaler=StandardScaler()
scaler.fit(archivo2) # calculo la media para poder hacer la transformacion
X_scaled=scaler.transform(archivo2)# Ahora si, escalo los datos y los normalizo
pca=PCA(n_components=1,whiten=True) # Otra opción es instanciar pca sólo con dimensiones nuevas hasta obtener un mínimo "explicado" ej.: pca=PCA(.85)
xpca=pca.fit_transform(X_scaled)
xpca.min()
# Out:
# -1.0433090845539077

# %%
df = pd.DataFrame()

# %%
df["IM"]=xpca.flatten()

# %%
xpca.flatten().shape==archivo2["entidad_federativa"].shape
# Out:
# True

# %%
df["entidad"]=archivo2["entidad_federativa"]
df
# Out:
#              entidad
# 0     Aguascalientes
# 1     Aguascalientes
# 2     Aguascalientes
# 3     Aguascalientes
# 4     Aguascalientes
# ...              ...
# 2441       Zacatecas
# 2442       Zacatecas
# 2443       Zacatecas
# 2444       Zacatecas
# 2445       Zacatecas
#
# [2445 rows x 1 columns]

# %%
df["municipio"]=archivo2["mun_name"]
df.head()
# Out:
#           entidad       municipio        IM
# 0  Aguascalientes  Aguascalientes  4.497571
# 1  Aguascalientes        Asientos  0.234134
# 2  Aguascalientes        Calvillo  0.238651
# 3  Aguascalientes           Cosío  0.186682
# 4  Aguascalientes     Jesús María  1.012726

# %%
scaler=StandardScaler()
df=archivo3
scaler.fit(df) # calculo la media para poder hacer la transformacion
X_scaled=scaler.transform(df)# Ahora si, escalo los datos y los normalizo

# %%
escalar=StandardScaler()
x=escalar.fit_transform(archivo3)
pca=PCA(n_components=1, whiten=True)
xpca=pca.fit_transform(x)
xpca.shape
xpca.max()
xpca.min()
# Out:
# -0.981931513020053

# %%
#DIVIDIR EN ESTRATOS
# Datos agrupados 
grouped_data =df.groupby('entidad')
grouped_data.head()
# Out:
#              entidad       municipio        IM
# 0     Aguascalientes  Aguascalientes  4.497571
# 1     Aguascalientes        Asientos  0.234134
# 2     Aguascalientes        Calvillo  0.238651
# 3     Aguascalientes           Cosío  0.186682
# 4     Aguascalientes     Jesús María  1.012726
# ...              ...             ...       ...
# 2388       Zacatecas          Apozol -0.130788
# 2389       Zacatecas          Apulco -0.313271
# 2390       Zacatecas        Atolinga -0.182136
# 2391       Zacatecas   Benito Juárez -0.279734
# 2392       Zacatecas          Calera  0.424717
#
# [160 rows x 3 columns]

# %%
final=grouped_data.mean()
final
# Out:
#                            IM
# entidad
# Aguascalientes       0.718622
# Baja California      4.045654
# Baja California Sur  1.128450
# Campeche             0.387002
# Chiapas             -0.162577
# Chihuahua            0.259726
# Coahuila             0.754437
# Colima               0.509251
# Distrito Federal     2.925760
# Durango              0.121256
# Guanajuato           0.696626
# Guerrero            -0.139446
# Hidalgo              0.037412
# Jalisco              0.308852
# Michoacán           -0.012796
# Morelos              0.256888
# México               0.799747
# Nayarit              0.306460
# Nuevo León           0.686041
# Oaxaca              -0.584132
# Puebla              -0.289982
# Querétaro            0.562224
# Quintana Roo         0.941508
# San Luis Potosí      0.011473
# Sinaloa              0.927783
# Sonora               0.425165
# Tabasco              0.943842
# Tamaulipas           0.322412
# Tlaxcala             0.056355
# ...

# %%
by_year = final.sort_values('IM')
by_year
# Out:
#                            IM
# entidad
# Oaxaca              -0.584132
# Puebla              -0.289982
# Yucatán             -0.221979
# Chiapas             -0.162577
# Guerrero            -0.139446
# Veracruz            -0.075005
# Michoacán           -0.012796
# San Luis Potosí      0.011473
# Zacatecas            0.037188
# Hidalgo              0.037412
# Tlaxcala             0.056355
# Durango              0.121256
# Morelos              0.256888
# Chihuahua            0.259726
# Nayarit              0.306460
# Jalisco              0.308852
# Tamaulipas           0.322412
# Campeche             0.387002
# Sonora               0.425165
# Colima               0.509251
# Querétaro            0.562224
# Nuevo León           0.686041
# Guanajuato           0.696626
# Aguascalientes       0.718622
# Coahuila             0.754437
# México               0.799747
# Sinaloa              0.927783
# Quintana Roo         0.941508
# Tabasco              0.943842
# ...

# %%
new=by_year.transpose()
new.head()
# Out:
# entidad    Oaxaca    Puebla   Yucatán   Chiapas  Guerrero  Veracruz  \
# IM      -0.584132 -0.289982 -0.221979 -0.162577 -0.139446 -0.075005
#
# entidad  Michoacán  San Luis Potosí  Zacatecas   Hidalgo  Tlaxcala   Durango  \
# IM       -0.012796         0.011473   0.037188  0.037412  0.056355  0.121256
#
# entidad   Morelos  Chihuahua  Nayarit   Jalisco  Tamaulipas  Campeche  \
# IM       0.256888   0.259726  0.30646  0.308852    0.322412  0.387002
#
# entidad    Sonora    Colima  Querétaro  Nuevo León  Guanajuato  \
# IM       0.425165  0.509251   0.562224    0.686041    0.696626
#
# entidad  Aguascalientes  Coahuila    México   Sinaloa  Quintana Roo   Tabasco  \
# IM             0.718622  0.754437  0.799747  0.927783      0.941508  0.943842
#
# entidad  Baja California Sur  Distrito Federal  Baja California
# IM                   1.12845           2.92576         4.045654

# %%
new.to_csv("C:/Users/Ariadna Cordero/Downloads/perfecto.csv")

# %%
df
# Out:
#              entidad              municipio        IM
# 0     Aguascalientes         Aguascalientes  4.497571
# 1     Aguascalientes               Asientos  0.234134
# 2     Aguascalientes               Calvillo  0.238651
# 3     Aguascalientes                  Cosío  0.186682
# 4     Aguascalientes            Jesús María  1.012726
# ...              ...                    ...       ...
# 2441       Zacatecas          Villa Hidalgo -0.168240
# 2442       Zacatecas             Villanueva  0.068231
# 2443       Zacatecas              Zacatecas  1.147529
# 2444       Zacatecas               Trancoso -0.037391
# 2445       Zacatecas  Santa María de la Paz -0.129148
#
# [2445 rows x 3 columns]

# %%
#Estrato1=BJ,DF,BJS,T,QR,S,M,G 15%
#ESTRATO2=A,C,NL,Q,C,C,S,T  20%
#ESTRATO3=N,J,M,C,D,T,H,Z   25%
#ESTRATO4=O,P,Y,C,G,V,M,SLP 40%
estrato4.shape
# Out:
# (1470, 3)

# %%
estrato1=df[df.entidad.isin(["Baja California","Distrito Federal","Baja California Sur","Tabasco","Quintana Roo","Sinaloa","México","Guanajuanto"])]

# %%
estrato2=df[df.entidad.isin(["Aguascalientes","Coahuila","Nuevo León","Querétaro","Colima","Campeche","Sonora","Tamanulipas"])]

# %%
estrato3=df[df.entidad.isin(["Nayarit","Jalisco","Morelos","Chihuahua","Durango","Tlaxcala","Hidalgo","Zacatecas"])]

# %%
estrato4=df[df.entidad.isin(["San Luis Potosí","Michoacán","Veracruz","Guerrero","Chiapas","Yucatán","Puebla","Oaxaca"])]

# %%
estrato1.sort_values('IM')
# Out:
#               entidad            municipio         IM
# 691            México      Ixtapan del Oro  -0.679590
# 716            México           Otzoloapan  -0.534790
# 767            México            Zacualpan  -0.420161
# 769            México          Zumpahuacán  -0.411080
# 684            México            Ecatzingo  -0.388743
# ..                ...                  ...        ...
# 708            México       Nezahualcóyotl   6.072837
# 681            México         Chimalhuacán   6.281025
# 14    Baja California              Tijuana   9.193208
# 265  Distrito Federal           Iztapalapa   9.939006
# 683            México  Ecatepec de Morelos  11.631228
#
# [196 rows x 3 columns]

# %%
dos .head()
# Out:
#     entidad        municipio        IM    y
# 691  México  Ixtapan del Oro -0.679590  1.0
# 716  México       Otzoloapan -0.534790  1.0
# 767  México        Zacualpan -0.420161  1.0
# 769  México      Zumpahuacán -0.411080  1.0
# 684  México        Ecatzingo -0.388743  1.0

# %%
#30 becas #166 ceros 
uno_acomoda=estrato1.sort_values('IM')
uno_acomoda
a = np.ones((30))
b = np.zeros((166))
c = np.concatenate((a, b), axis=0)

# %%
uno_acomoda["y"]=c

# %%
estrato2.shape
#42 becas #167 ceros
dos_acomoda=estrato2.sort_values('IM')
a = np.ones((42))
b = np.zeros((167))
c = np.concatenate((a, b), axis=0)
dos_acomoda["y"]=c

# %%
estrato3.shape
#120 becas #361 ceros
tres_acomoda=estrato3.sort_values('IM')
a = np.ones((120))
b = np.zeros((361))
c = np.concatenate((a, b), axis=0)
tres_acomoda["y"]=c

# %%
estrato4.shape
#588 becas #882 ceros
cuatro_acomoda=estrato4.sort_values('IM')
a = np.ones((588))
b = np.zeros((882))
c = np.concatenate((a, b), axis=0)
cuatro_acomoda["y"]=c

# %%
base_final=pd.concat([uno_acomoda,dos_acomoda,tres_acomoda,cuatro_acomoda], axis=0)
base_final.head()
# Out:
#     entidad        municipio        IM    y
# 691  México  Ixtapan del Oro -0.679590  1.0
# 716  México       Otzoloapan -0.534790  1.0
# 767  México        Zacualpan -0.420161  1.0
# 769  México      Zumpahuacán -0.411080  1.0
# 684  México        Ecatzingo -0.388743  1.0

# %%
import geopandas
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#mex=geopandas.read_file("C:/Users/Ariadna Cordero/Downloads/mexican-states.shp",encoding='utf-8')
mex["name"]
# Out:
# 0          Aguascalientes
# 1                  Colima
# 2                Tlaxcala
# 3        Distrito Federal
# 4                 Morelos
# 5                  México
# 6                 Hidalgo
# 7                  Puebla
# 8              Nuevo León
# 9                Coahuila
# 10              Chihuahua
# 11                 Sonora
# 12              Michoacán
# 13              Querétaro
# 14             Guanajuato
# 15                Jalisco
# 16              Zacatecas
# 17                Durango
# 18             Tamaulipas
# 19               Veracruz
# 20               Guerrero
# 21                Sinaloa
# 22                 Oaxaca
# 23                Nayarit
# 24                Chiapas
# 25                Tabasco
# 26               Campeche
# 27        Baja California
# 28    Baja California Sur
# 29        San Luis Potosí
# 30                Yucatán
# 31           Quintana Roo
# Name: name, dtype: object

# %%
mex["name"][3]="Distrito Federal"
# Out:
# C:\Users\Ariadna Cordero\.conda\envs\optimization\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
finalbase = base_final.merge(
                     right = archivo,
                     left_on = 'municipio',
                     right_on = 'mun_name',
                     how = 'left'
                     )

# %%
ff.head()
# Out:
#          municipio        IM    y  Unnamed: 0  clave_entidad  \
# 0  Ixtapan del Oro -0.679590  1.0         696             15
# 1       Otzoloapan -0.534790  1.0         721             15
# 2        Zacualpan -0.420161  1.0         772             15
# 3        Zacualpan -0.420161  1.0         925             17
# 4        Zacualpan -0.420161  1.0        2278             30
#
#   entidad_federativa clave_municipio         mun_name  poblacion  pobreza  \
# 0             México           15041  Ixtapan del Oro       7114     89.2
# 1             México           15066       Otzoloapan       4055     78.2
# 2             México           15117        Zacualpan      13160     76.1
# 3            Morelos           17032        Zacualpan       9489     70.7
# 4           Veracruz           30198        Zacualpan       7154     84.5
#
#    pobreza_pob  pobreza_e  pobreza_e_pob  pobreza_m  pobreza_m_pob  vul_car  \
# ...

# %%
ff=ffe.drop(["entidad"],axis=1)
